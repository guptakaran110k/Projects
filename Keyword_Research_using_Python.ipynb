# %% [markdown]
# <a href="https://colab.research.google.com/github/guptakaran110k/Projects/blob/main/Keyword_Research_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list = ["Data Science"])
data = trends.interest_by_region()
print(data.sample(10))
# Out:
#                    Data Science
# geoName
# Trinidad & Tobago             0
# Chile                        14
# Sri Lanka                    53
# Réunion                       0
# Mauritius                     0
# Bhutan                        0
# Vietnam                      16
# Haiti                         0
# Morocco                      29
# Ethiopia                     83

# %%
df = data.sample(15)
df.reset_index().plot(x="geoName",y="Data Science", kind = "bar")
plt.show()

# %%
data = trends.trending_searches(pn="india")
print(data.head(10))
# Out:
#                                0
# 0               SBFC share price
# 1                       MS Dhoni
# 2                    Darren Kent
# 3        16 August 2023 Panchang
# 4                  Saif Ali Khan
# 5                 Bittu Bajrangi
# 6  Bigg Boss OTT season 2 winner
# 7           Man United vs Wolves
# 8                          Taali
# 9                   Burj Khalifa

# %%
data = trends.trending_searches(pn="australia")
print(data.head(10))
# Out:
#                                  0
# 0                      Inter Miami
# 1                      Good Things
# 2                      Darren Kent
# 3                          Matilda
# 4                      Teddy Swims
# 5                     Lidia Thorpe
# 6                    Elvis Presley
# 7                       Tim Sheens
# 8            How to watch Matildas
# 9  Football Women's World Cup 2023

# %%
keyword = trends.suggestions(keyword="Data Science")
data = pd.DataFrame(keyword)
print(data.head())
# Out:
#              mid                                              title  \
# 0     /m/0jt3_q3                                       Data science
# 1  /g/11j5h1w_jl                              The Soulmate Equation
# 2  /g/11jwx42d8t  Finding the Mother Tree: Discovering the Wisdo...
# 3  /g/11h191mm4z                   Mathematics for Machine Learning
# 4  /g/11cs04mpv3  Python for Everybody: Exploring Data Using Pyt...
#
#                                                 type
# 0                                     Field of study
# 1                           Book by Christina Lauren
# 2                             Book by Suzanne Simard
# 3  Book by A. Aldo Faisal, Cheng Soon Ong, and Ma...
# 4                          Book by Charles Severance
